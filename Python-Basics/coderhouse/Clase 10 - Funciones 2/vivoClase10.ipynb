# %% [markdown]
# # Repaso y ejercicios

# %% [markdown]
# #Ejercicio 0
# Crea una función esMultiplo que reciba los dos números, y devuelve si el primero es múltiplo del segundo.
#
# #Ejercicio 1
# Crea un programa que pida dos número enteros al usuario y diga si alguno de ellos es múltiplo del otro.
#
#
# #Ejercicio 2
# Crear una función que calcule la temperatura media de un día a partir de la temperatura máxima y mínima.
#
# #Ejercicio 3
# Crear un programa principal, que utilizando la función anterior, vaya pidiendo la temperatura máxima y mínima de cada día y vaya mostrando la media. El programa pedirá el número de días que se van a introducir.
#
#
# #Ejercicio 4
# Crea una función “calcularMaxMin” que recibe una lista con valores numéricos y devuelve el valor máximo y el mínimo.
#
#
# #Ejercicio 6
# Diseñar una función que calcule el área y el perímetro de una circunferencia.
#
# #Ejercicio 7
# Crear una subrutina llamada “Login”, que recibe un nombre de usuario y una contraseña y te devuelve Verdadero si el nombre de usuario es “usuario1” y la contraseña es “asdasd”.
#
# #Ejercicio 8
# Crear un programa principal donde se pida un nombre de usuario y una contraseña y se intente hacer login, solamente tenemos tres oportunidades para intentarlo.
#
# #Ejercicio 9
# Crear una función  que permita calcular el factorial de un número.

# %%
diccionario_datos_persona = {} #diccionario sin nada

diccionario_datos_persona["NOMBRE"] = input( "Por favor ingresar tu nombre:\n" )
diccionario_datos_persona["APELLIDO"] = input( "Por favor ingresar tu apellido:\n" )
diccionario_datos_persona["EDAD"] = int (input( "Por favor ingresar tu edad:\n" ))
# Out:
# Por favor ingresar tu nombre:
# Nico
# Por favor ingresar tu apellido:
# Perez
# Por favor ingresar tu edad:
# 32

# %%
print("---------------------------\n")
print(f"    NOMBRE: {diccionario_datos_persona['NOMBRE']}")
print(f"    APELLIDO: {diccionario_datos_persona['APELLIDO']}")
print(f"    EDAD: {diccionario_datos_persona['EDAD']}")
print("\n---------------------------\n")
# Out:
# ---------------------------
#
#     NOMBRE: Nico
#     APELLIDO: Perez
#     EDAD: 32
#
# ---------------------------

# %%
#Función 

def pedirDatosDePersona():

  d = {}

  d["NOMBRE"] = input( "Por favor ingresar tu nombre:\n" )
  d["APELLIDO"] = input( "Por favor ingresar tu apellido:\n" )
  d["EDAD"] = int (input( "Por favor ingresar tu edad:\n" ))

  return d

# %%
def mostrarDatosDePersona(datosPersona):


  print("---------------------------\n")
  print(f"    NOMBRE: {datosPersona['NOMBRE']}")
  print(f"    APELLIDO: {datosPersona['APELLIDO']}")
  print(f"    EDAD: {datosPersona['EDAD']}")
  print("\n---------------------------\n")

# %%
diccionario1 = {}

# %%
diccionario1
# Out:
# {}

# %%
diccionario1 = pedirDatosDePersona()
# Out:
# Por favor ingresar tu nombre:
# Marcelo
# Por favor ingresar tu apellido:
# Long
# Por favor ingresar tu edad:
# 41

# %%
diccionario1
# Out:
# {'APELLIDO': 'Long', 'EDAD': 41, 'NOMBRE': 'Marcelo'}

# %%
mostrarDatosDePersona(diccionario1)
# Out:
# ---------------------------
#
#     NOMBRE: Marcelo
#     APELLIDO: Long
#     EDAD: 41
#
# ---------------------------

# %%
x = pedirDatosDePersona()
mostrarDatosDePersona(x)
# Out:
# Por favor ingresar tu nombre:
# Brenda
# Por favor ingresar tu apellido:
# Gomez
# Por favor ingresar tu edad:
# 17
# ---------------------------
#
#     NOMBRE: Brenda
#     APELLIDO: Gomez
#     EDAD: 17
#
# ---------------------------

# %%
#PRO!!!

mostrarDatosDePersona(pedirDatosDePersona())
# Out:
# Por favor ingresar tu nombre:
# Laura
# Por favor ingresar tu apellido:
# ANtonelli
# Por favor ingresar tu edad:
# 22
# ---------------------------
#
#     NOMBRE: Laura
#     APELLIDO: ANtonelli
#     EDAD: 22
#
# ---------------------------

# %%
numero =  5 #Se define una varaible que se llama numero<--- 5

# %%
def duplicar(nume):  #recibe un valor y lo guarda en una variable que se llam nume

  nume = nume*2      #Nume es un variable local de mi funcion

# %%
duplicar(numero)  #<----le doy el 5.... lo llama nume.... y lo duplica

# %%
print(f"{numero}")
# Out:
# 5

# %%
#print(f"{nume}")

# %%
lista = [2,3,-1]

# %%
def triplicar(listita):

  pos = 0

  for x in listita:

    listita[pos] = x*3
    pos = pos +1

# %%
triplicar(lista)

# %%
lista
# Out:
# [6, 9, -3]

# %%
def resta(a=0, b=0):
		return a - b

# %%
resta(20,11)
# Out:
# 9

# %%
resta(15)
# Out:
# 15

# %%
resta()
# Out:
# 0

# %%
resta(b=31)
# Out:
# -31

# %%
def doblar_valores(numeros):

  for i,n in enumerate(numeros):

    numeros[i] *=2

# %%
#numeros ---- No se ac
listaDeNico = [10,50,100]

# %%
doblar_valores(listaDeNico)

# %%
listaDeNico
# Out:
# [20, 100, 200]

# %%
def cuenta(numero):

  numero -=1

  if numero >0: 

    cuenta(numero)
    print(f"---->{numero}")

# %%
cuenta(7)
# Out:
# ---->1
# ---->2
# ---->3
# ---->4
# ---->5
# ---->6

# %%
#Factorial de un numero ----- 3!  --- 3.2.1
