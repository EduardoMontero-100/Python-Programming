# %%
print(variable2)
variable2="hola"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-007ec7d1a5b9> in <module>()
# ----> 1 print(variable2)
#       2 variable2="hola"
#       3
#       4
#
# NameError: name 'variable2' is not defined

# %%
variable1=93
print(variable1)
# Out:
# 93
