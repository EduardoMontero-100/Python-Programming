# %%
mensaje1="hola mundo"
print(mensaje1)
mensaje2="Bienvenidos a coder"
print(mensaje1)

# %% [markdown]
# NUMEROS
#
# ENTEROS: int | (long con una L)
#
# PUNTO FLOTANTE: float | decimal
#
# COMPLEJOS: complex

# %%
4+(4*6-2)**2

# %% [markdown]
# Operaciones con Numeros
#
# OPERACIONES ARITMETICAS
#
# ![image.png](data:image/png;base64,...)
#
# PRECEDENCIA DE LOS OPERADORES:
#
# ![image.png](data:image/png;base64,...)

# %%
#PRINT   <- comentario :) 

#probamos distintas operaciones

print(f"La edad de Fran es {27+9} :) --> {33 % 4} ")
# Out:
# La edad de Fran es 32 :) --> 1

# %% [markdown]
# CADENAS DE TEXTO
#
# Son de tipo str y se delimitan indistintamente con "" o con ''
#
# ** Caracteres de escape en Py:**
#
# Ejemplos:
#
# “Esto es un ‘texto’ entre comillas dobles”
#
# ‘Esto es otro “texto” entre comillas simples’
#
# “Esto es otro \“texto\” todo en comillas dobles”
#
# ‘Esto otro \’texto\’ todo en comillas simples’

# %% [markdown]
# VAMOS A LAS FILMINAS PREVIO AL BREAK?

# %%
print("Hola"+" Mundo "+"\nComo estan por alla")

# %%
print("C:\nombre\directorio {23+9}")

# %% [markdown]
# BREAK!!

# %% [markdown]
# ***Arrancamos con variables :) ***

# %%
#IMC   peso / altura al cuadrado en metros

#Cómo nombrar a las variables????
#1) Minuscula !!!!!
#2) todo en miniscula, menos la primer letra de la palabra 2 y 3 y 4 (camelCase)
#3) snakeCase

#QUE PASA SI NO LA DEFINO PREVIO?
suma =3+5

print(suma)
resta=3-6
suma=98.5
palabra="hola"


#print("hola"*3 )

# %% [markdown]
# QUE PASA SI CAMBIO EL VALOR?

# %%
variableNueva = 11

# %% [markdown]
# QUE OTRO METODO TENGO PARA DARLE VALOR A UNA VARIABLE?
#
#
# INPUT

# %%
nombreProfe = "Franco Di Martino"

# %%
print(nombreProfe)

# %%
dato_entrante = input()

# %%
print(dato_entrante)

# %%
nombre = input("¿Cómo te llamas?")

# %%
print(nombre)

# %% [markdown]
# COMO HAGO PARA OBTENER UN ENTERO? Y UN FLOAT?

# %%
vble=input("ingresame un numero")
print(vble**2)

# %%
altura = 1.83
peso = 87

# %%
imc = peso / (altura**2)

# %%
imc

# %% [markdown]
# TRABAJAMOS CON STRINGS?
#
# CONCATENAMOS?
#
# INDEXACION
#
# LONGITUD
#
# SLICING
#
# REASIGNAMOS?

# %%
cadena="hola"
cadena2="mundo"
concatenacion=cadena+" "+cadena2

print(cadena)

# %%
cadena_1  = "moderno"
cadena_2  = "Python"
 cadena_3  = "es un lenguaje"
 cadena_4  = "de programación"


#como armamos la frase?

# %%
#indexacion
#longitud

# %%
#slicing ATENCION
#Vamos a filmina!
cad="CadenaDeTextoParaJugarConSlicing"
# Out:
# gnicilSnoCraguJaraPotxeTeDaneda

# %%
ejercicioSlicing = "acitametaM ,5.8 ,otipeP ordeP"

# %%
#reasignamos, concepto de mutabilidad

lenguaje="Pithon"

# %%
prod=9
prode=7
print(prod+prode)

# %%
#ver Examenes y promedio. simple
